# %%
# A. Creating and customizing line charts using Matplotlib

# %%
import pandas as pd
iris_df = pd.read_csv('iris.csv')

# %%
type(iris_df)
# Out:
# pandas.core.frame.DataFrame

# %%
iris_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
iris_df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.figure(figsize=(10, 5))
plt.title('Matplot Line Chart')
sns.set_style('darkgrid')
plt.plot(iris_df.sepal_length, iris_df.sepal_width)

# %%
# B. Visualizing relationships between two or more variables using scatter plots

# %%
plt.figure(figsize=(10, 5))
plt.title('Relation between Sepal Length and Sepal Width')

sns.scatterplot(x=iris_df.sepal_length, 
                y=iris_df.sepal_width, 
                hue=iris_df.variety,
               s=50);

# %%
# C. Studying distributions of variables using histograms & bar charts to

# %%
iris_df = sns.load_dataset('iris')

# %%
iris_df.sepal_width
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
plt.title('Histrogram')
plt.hist(iris_df.sepal_width);

# %%
#bar charts

# %%
years = range(2000, 2006)
cycle = [0.35, 0.6, 0.9, 0.8, 0.65, 0.8]
bike = [0.4, 0.8, 0.9, 0.7, 0.6, 0.8]

# %%
plt.bar(years, cycle);
plt.plot(years, cycle, 's--r');

# %%
plt.bar(years, bike);
plt.bar(years, cycle, bottom=bike);
plt.legend(['bike', 'cycle']);

# %%
#  D. Visualizing two-dimensional data using heatmaps

# %%
import pandas as pd 
flights_df = pd.read_csv('flights.csv')
sample_df = sns.load_dataset('flights')

# %%
sample_df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
import warnings
warnings.filterwarnings('ignore') # For remove warnings

flights_df = sns.load_dataset('flights').pivot('month','year','passengers')
flights_df
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
plt.title('Numbers of passengers')
sns.heatmap(flights_df, fmt='d', annot=True, cmap='Greens') # For show the numbers of passagers in box use "annot" & color
# Out:
# <Axes: title={'center': 'Numbers of passengers'}, xlabel='year', ylabel='month'>

# %%
# E. Displaying images using Matplotlib's plt.imshow

# %%
# %matplotlib inline

# %%
from PIL import Image

# %%
img = Image.open('bugati.png') # Load image file

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1600x1067>

# %%
import numpy as np
img_array = np.array(img)

# %%
img_array.shape
# Out:
# (1067, 1600, 4)

# %%
plt.imshow(img);

# %%
plt.grid(False) # For remove Grids
plt.imshow(img);
# Out:
# 3

# %%
plt.axis('off') # For not showing Axis
plt.imshow(img_array[100:800, 400:1200]); # For Show perticuler potion of Image file

# %%
# F. Plotting multiple Matplotlib and Seaborn charts in a grid

# %%
fig, axes = plt.subplots(2,2, figsize=(15,10))

# %%
fig, axes = plt.subplots(2,2, figsize=(15,10))

# Plotting
axes[0,0].plot(years, cycle, 's-b')
axes[0,0].plot(years, bike, 'o--r')
axes[0,0].set_xlabel('Year')
axes[0,0].set_ylabel('Yield')
axes[0,0].legend(['Cycle', 'Bike']);
axes[0,0].set_title('Yields in Ukreine')

# Scatter plot
axes[0,1].set_title('Sepal Length & Sepal Width')
sns.scatterplot(x=iris_df.sepal_length, y=iris_df.sepal_width, 
                hue=iris_df.variety, s=50, ax=axes[0,1]);

# Histrofram
axes[1,0].set_title('Distribution of Sepal')
axes[1,0].hist([iris_df.sepal_width, iris_df.sepal_width, iris_df.sepal_width], 
         bins=np.arange(2, 5, 0.25), 
         stacked=True);
axes[1,0].legend(['Setosa', 'Versicolor', 'Virginica']);

# Heatmap
axes[1,1].set_title('Flight traffic')
sns.heatmap(flights_df, cmap='Greens', ax=axes[1,1]);

plt.tight_layout(pad=5);

# %%
sns.pairplot(iris_df, hue='variety');
